# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Web Scraping Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab, you will be able to:

# %% [markdown]
# * Download a webpage using requests module
# * Scrape all links from a webpage
# * Scrape all image URLs from a web page
# * Scrape data from html tables

# %% [markdown]
# ## Scrape www.ibm.com

# %% [markdown]
# Import the required modules and functions

# %%
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a webpage

# %% [markdown]
# Download the contents of the webpage

# %%
url = "http://www.ibm.com"

# %%
# get the contents of the webpage in text format and store in a variable called data
data  = requests.get(url).text

# %% [markdown]
# Create a soup object using the class BeautifulSoup

# %%
soup = BeautifulSoup(data,"html.parser")  # create a soup object using the variable 'data'

# %% [markdown]
# Scrape all links

# %%
for link in soup.find_all('a'):  # in html anchor/link is represented by the tag <a>
    print(link.get('href'))
# Out:
# https://www.ibm.com/kr-ko/reports/data-breach?lnk=hpls1kr
# https://bob.ibm.com/trial?lnk=hprc1kr
# https://bob.ibm.com/blog/bob-v2-release-announcement?lnk=hprc2kr
# https://www.ibm.com/kr-ko/forms/webinars/mkt-webinar-94567?lnk=hprc3kr
# https://www.ibm.com/kr-ko/products/z17?lnk=hprc4kr
# https://www.ibm.com/kr-ko/new/announcements/clients-rank-ibm-among-top-enterprise-software-providers-in-2026-g2-best-software-awards?lnk=hpfp1kr
# https://bob.ibm.com?lnk=hpfp2kr
# https://www.ibm.com/kr-ko/products/watsonx-orchestrate?lnk=hpfp3kr
# https://www.ibm.com/kr-ko/products/confluent?lnk=hpfp4kr
# https://www.ibm.com/kr-ko/products/flashsystem?lnk=hpfp5kr
# https://www.hashicorp.com/ko/products/vault?lnk=hpfp6kr
# https://www.ibm.com/kr-ko/products/maximo?lnk=hpfp7kr
# https://www.ibm.com/kr-ko/products/planning-analytics?lnk=hpfp8kr
# https://www.ibm.com/kr-ko/consulting?lnk=hpfp9kr
# None
# https://www.ibm.com/kr-ko/case-studies/all-england-lawn-tennis-club-ibm-ix?lnk=hpcs1kr
# https://www.ibm.com/kr-ko/case-studies/riverty?lnk=hpcs2kr
# https://www.ibm.com/kr-ko/case-studies/citadelle?lnk=hpcs3kr
# https://www.ibm.com/kr-ko/case-studies/ibm-client-zero?lnk=hpcs4kr
# https://www.ibm.com/kr-ko/about?lnk=hpii1us
# https://research.ibm.com/?lnk=hpii1us
# https://www.ibm.com/quantum?lnk=hpii1us
# https://www.ibm.com/careers?lnk=inside
# https://skillsbuild.org/?lnk=inside
# https://kr.newsroom.ibm.com/announcements?item=122846
# https://kr.newsroom.ibm.com/announcements?item=122845
# https://kr.newsroom.ibm.com/announcements?item=122844
# https://kr.newsroom.ibm.com/announcements?item=122843
# https://kr.newsroom.ibm.com/announcements?item=122842
# https://kr.newsroom.ibm.com/announcements?item=122841
# https://kr.newsroom.ibm.com/announcements?item=122840
# https://kr.newsroom.ibm.com/announcements?item=122839

# %% [markdown]
# Scrape  all images

# %%
for link in soup.find_all('img'):# in html image is represented by the tag <img>
    #print(link)
    print(link.get('src'))
# Out:
# /adobe/dynamicmedia/deliver/dm-p-oid--obbxEfsIG4AR1RIjYghD_sREGoq1iSfulBnXzijzeV0LHmgJtRq_2lGJ_7kd9o8OARcIHMexBjNOMNv99JUxBZShZ2fpX1_hJ9y5vqze0djL4kZnqmvZ0blOUKsFHXwLxYhWle_McRSQyxDOWMNODTqkP6m6xA5JRqEZjdTxWNc/homepage-vault-r4u-bob-001-v2.png?preferwebp=true&quality=90
# https://assets.ibm.com/is/image/ibm/ibm_bob_consideration_dco_banner_970x250-1?ts=1786685142295&dpr=off
# /adobe/dynamicmedia/deliver/dm-p-oid--obbxEfsIG4AR1RIjYghD_sREGoq1iSfulBnXzijzeV0LHmgJtRq_2lGJ_7kd9o8OARcIHMexBjNOMNv99JUxBZShZ2fpX1_hJ9y5vqze0dgsCMkti8HmLXPLyXLYPuYeXWqoeS_V_vLP68OlZA4kyKVvJfPqDGWml84dysDuC2tcAR0KA67o_Ap4vZlu91m_/2025-wxo-sizzle-orchestrate-agentcardstower-1x1.png?preferwebp=true&quality=90
# /adobe/dynamicmedia/deliver/dm-p-oid--obbxEfsIG4AR1RIjYghD_sREGoq1iSfulBnXzijzeV0LHmgJtRq_2lGJ_7kd9o8OARcIHMexBjNOMNv99JUxBZShZ2fpX1_hJ9y5vqze0dg5mrsB-O6EvlL8u2tWqWYFtxExz9_1vYFbgzAT46tCxhM0yn_3ClyxeKJj4MPjc5w/20241218-ibm-znext-shot-06-1x1-v3.png?preferwebp=true&quality=90
# /adobe/dynamicmedia/deliver/dm-aid--5e7fd896-f60a-4ed2-9ee9-d394634e4a89/championships-logo-jpeg.jpg?preferwebp=true
# https://assets.ibm.com/is/image/ibm/riverty-logo-2x1?ts=1782887672074&dpr=off
# https://assets.ibm.com/is/image/ibm/citadelle-logo-2x1?ts=1782887691651&dpr=off
# https://assets.ibm.com/is/image/ibm/ibm-logo-2x1?ts=1782884230728&dpr=off
# https://assets.ibm.com/is/image/ibm/homepage-training-professional-4x3?ts=1781089217709&dpr=off
# https://assets.ibm.com/is/image/ibm/homepage-training-foundational-4x3?ts=1781089217910&dpr=off
# https://assets.ibm.com/is/image/ibm/homepage-training-students-4x3?ts=1781089218191&dpr=off
# https://assets.ibm.com/is/image/ibm/stay-connected-homepage-people-16x9?ts=1782869788197&dpr=off

# %% [markdown]
# ## Scrape data from html tables

# %%
#The below URL contains a html table with data about colors and color codes.
URL = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/HTMLColorCodes.html"

# %% [markdown]
# Before proceeding to scrape a website, you need to examine the contents, and the way data is organized on the website. Open the above URL in your browser and check how many rows and columns are there in the color table.

# %%
# get the contents of the webpage in text format and store in a variable called data
data  = requests.get(URL).text

# %%
soup = BeautifulSoup(data,"html.parser")

# %%
#find a html table in the web page
table = soup.find('table') # in html table is represented by the tag <table>

# %% [markdown]
# # Get all rows from the table

# %%
for row in table.find_all('tr'): # in html table row is represented by the tag <tr>
    # Get all columns in each row.
    cols = row.find_all('td') # in html a column is represented by the tag <td>
    color_name = cols[2].getText() # store the value in column 3 as color_name
    color_code = cols[3].getText() # store the value in column 4 as color_code
    print("{}--->{}".format(color_name,color_code))
# Out:
# Color Name--->Hex Code#RRGGBB
# lightsalmon--->#FFA07A
# salmon--->#FA8072
# darksalmon--->#E9967A
# lightcoral--->#F08080
# coral--->#FF7F50
# tomato--->#FF6347
# orangered--->#FF4500
# gold--->#FFD700
# orange--->#FFA500
# darkorange--->#FF8C00
# lightyellow--->#FFFFE0
# lemonchiffon--->#FFFACD
# papayawhip--->#FFEFD5
# moccasin--->#FFE4B5
# peachpuff--->#FFDAB9
# palegoldenrod--->#EEE8AA
# khaki--->#F0E68C
# darkkhaki--->#BDB76B
# yellow--->#FFFF00
# lawngreen--->#7CFC00
# chartreuse--->#7FFF00
# limegreen--->#32CD32
# lime--->#00FF00
# forestgreen--->#228B22
# green--->#008000
# powderblue--->#B0E0E6
# lightblue--->#ADD8E6
# lightskyblue--->#87CEFA
# skyblue--->#87CEEB
# deepskyblue--->#00BFFF
# lightsteelblue--->#B0C4DE
# dodgerblue--->#1E90FF

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# <!--
# ## Change Log
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2024-10-29  | 0.2  | Madhusudhan Moole |  Updated lab |
# | 2020-10-17  | 0.1  | Ramesh Sannareddy  |  Created initial version of the lab |
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
